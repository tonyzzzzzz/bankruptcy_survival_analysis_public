# %% [markdown]
# ## Data exploration

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load datasets

# %%
raw_data = pd.read_csv('../data/data_for_bankruptcy_prediction_no_lags_corrected.csv', index_col=[1, 0])
raw_data.sort_index()
# Out:
#                  ActAt     ActLct   ActSale   AltSeqAt    ApSale     AtSale  \
# gvkey  fyear
# 1004   1983   0.674250   2.520938  0.520505   0.987578  0.123536   0.771976
#        1984   0.659271   2.251489  0.467942   0.981532  0.090776   0.709787
#        1985   0.709784   2.008176  0.567477   0.920835  0.098588   0.799506
#        1986   0.718658   2.078003  0.566581   0.890890  0.089701   0.788388
#        1987   0.731344   2.029756  0.599456   0.821853  0.094000   0.819664
# ...                ...        ...       ...        ...       ...        ...
# 317264 2016   0.036634   0.745887  0.376615   7.781250  0.041658  10.280558
#        2017   0.080699   1.648665  0.835209   7.873167  0.039096   6.238926
# 317427 2016   0.185540   1.160271  0.453286  -2.574968  0.178970   2.443067
#        2017   0.162788   1.067246  0.382858  -2.620971  0.168097   2.351886
# 318005 2017   0.925591  12.233814  8.890923  21.695087  0.106516   8.990403
#
# ...

# %% [markdown]
# #### Visualizations
